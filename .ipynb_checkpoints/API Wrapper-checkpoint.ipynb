# %% [markdown]
# ## API Wrapper

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("C:\\Users\\franc\\OneDrive\\Área de Trabalho\Data Analytics\\Week 2\\6.05 API Wrappers, Spotipy\\secrets.txt","r")
string = secrets_file.read()
string.split('\n')
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %%
#Small list test
playlist_test = sp.user_playlist_tracks("spotify", "37i9dQZEVXbMDoHDwVN2tF")

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
test = get_playlist_tracks('37i9dQZEVXbMDoHDwVN2tF')

# %%
#From playlist, get artist
def get_artist_from_playlist(playlist):
    artists = []
    for i in range(len(playlist)):
        if playlist[i]["track"]["artists"][0]["name"] not in artists:
            artists.append(playlist[i]["track"]["artists"][0]["name"])
    return artists
    
#From artists, get info
def get_artist_info(artist_list):
    artist_info = []
    for i in artist_list:
        results = sp.search(q=i, limit=50)
        artist_info.append(results)
    return artist_info

#From artist info, get album
def get_album(artist_info):
    albums = []
    for i in range(len(artist_info)):
        if artist_info[i]["tracks"]["items"][0]["album"]["name"] not in artist_info:
            album_uri.append(artist_info[i]["tracks"]["items"][0]["album"]["name"])
    return albums

#From album, get songs
def get_album_songs(albums):
    song_uri = []
    for i in album_uri:
        results = sp.search(q=i, limit=50)
        song_uri.append(results)
    return artist_info

# %%
playlist = sp.user_playlist_tracks("spotify", "1OfeGWEHudCL9mtqoR6Os8")

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist["items"][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
playlist["total"]
# Out:
# 5550

# %%
len(playlist["items"])
# Out:
# 100

# %%
playlist['next'] #link to the next set of results
# Out:
# 'https://api.spotify.com/v1/playlists/1OfeGWEHudCL9mtqoR6Os8/tracks?offset=100&limit=100&additional_types=track'

# %%
all_tracks = get_playlist_tracks("1OfeGWEHudCL9mtqoR6Os8")
len(all_tracks)
# Out:
# 5550

# %%
all_tracks[0]["track"]["artists"][0]["name"]
# Out:
# 'Fiona Apple'

# %% [markdown]
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
#From playlist, get artist

def get_artist_from_playlist(playlist):
    artists = []
    for i in range(len(playlist)):
        if playlist[i]["track"]["artists"][0]["name"] not in artists:
            artists = artists.append(playlist[i]["track"]["artists"][0]["name"])
    

From artist get info
def artist_info(artist_list):
    artist_info = []
    for i in artist_list:
        results = sp.search(q=i, limit=50)
        artist_info.append(results)
    return artist_info

# %%
artists = get_artist_from_playlist(all_tracks)

# %%
artists
# Out:
# ['Fiona Apple',
#  'Phoebe Bridgers',
#  'Brian Johannesen',
#  'Waxahatchee',
#  'The Lone Bellow',
#  'Mt. Joy',
#  'Futurebirds',
#  'Dave Simonett',
#  'Marcus King',
#  'Clem Snide',
#  'Jonathan Wilson',
#  'Bonny Light Horseman',
#  'Aubrie Sellers',
#  'Lucinda Williams',
#  'Basia Bulat',
#  'Swamp Dogg',
#  'Mondo Cozmo',
#  'Darrell Scott',
#  'Jake Bugg',
#  'Perfume Genius',
#  'Drive-By Truckers',
#  'Reckless Kelly',
#  'Christopher Paul Stelling',
#  'Ray LaMontagne',
#  'Mary Chapin Carpenter',
#  'Nicole Atkins',
#  'Charley Crockett',
#  'Pearl Jam',
#  'My Morning Jacket',
#  'Passenger',
#  'Alberta Cross',
#  'Courtney Marie Andrews',
#  'Pretenders',
#  'Bright Eyes',
#  'Delta Spirit',
#  'Chuck Prophet',
#  'Jason Isbell and the 400 Unit',
#  'Gasoline Lollipops',
#  'Sarah Jarosz',
#  'Woods',
#  'Waylon Payne',
#  'The Jayhawks',
#  'Ratboys',
#  'The Whiskey Treaty Roadshow',
#  'Becca Mancari',
#  'The War and Treaty',
#  'Low Cut Connie',
# ...

# %%
artist_info(artists)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7108/3457371831.py in <module>
# ----> 1 artist_info(artists)
#
# ~\anaconda3\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# ~\anaconda3\lib\site-packages\IPython\core\displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ...

# %%
#From artists info, get albums
albums = []
for i in artists:
    results = sp.search
# Out:
# ['Fiona Apple',
#  'Phoebe Bridgers',
#  'Brian Johannesen',
#  'Waxahatchee',
#  'The Lone Bellow',
#  'Mt. Joy',
#  'Futurebirds',
#  'Dave Simonett',
#  'Waxahatchee',
#  'Marcus King',
#  'Marcus King',
#  'The Lone Bellow',
#  'Waxahatchee',
#  'Clem Snide',
#  'Jonathan Wilson',
#  'Bonny Light Horseman',
#  'The Lone Bellow',
#  'Aubrie Sellers',
#  'The Lone Bellow',
#  'Lucinda Williams',
#  'Dave Simonett',
#  'Basia Bulat',
#  'Swamp Dogg',
#  'Lucinda Williams',
#  'Swamp Dogg',
#  'Aubrie Sellers',
#  'Mt. Joy',
#  'Mondo Cozmo',
#  'Marcus King',
#  'Futurebirds',
#  'Swamp Dogg',
#  'Mt. Joy',
#  'Futurebirds',
#  'Darrell Scott',
#  'Jake Bugg',
#  'Mt. Joy',
#  'Perfume Genius',
#  'Drive-By Truckers',
#  'Reckless Kelly',
#  'Christopher Paul Stelling',
#  'Lucinda Williams',
#  'Ray LaMontagne',
#  'Mary Chapin Carpenter',
#  'Nicole Atkins',
#  'Charley Crockett',
#  'Pearl Jam',
#  'My Morning Jacket',
#  'My Morning Jacket',
#  'My Morning Jacket',
# ...

# %%
artist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7108/1246515200.py in <module>
# ----> 1 artist
#
# NameError: name 'artist' is not defined

# %%
#From artists, get albums
def get_album_from_artist(tracks):

# %%
#From albums, get songs
def get_song_uri_from_album(tracks):

# %%
songs_uri = 

len(all_tracks)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7108/1513334600.py in <module>
# ----> 1 get_name_albums_from_track(all_tracks)
#
# ~\AppData\Local\Temp/ipykernel_7108/1212702416.py in get_name_albums_from_track(tracks)
#       1 def get_name_albums_from_track(tracks):
# ----> 2     return [(track['album'],album['name']) for track in tracks['track']]
#
# TypeError: list indices must be integers or slices, not str

# %%
# get the uri of a single song:
song_uri = playlist["items"][46]["track"]["uri"]

# %%
# get the audio features for that song
sp.audio_features(song_uri)

# %%
# Track name
results["tracks"]["items"][0]["name"]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7108/3162023602.py in <module>
# ----> 1 get_name_artists_from_track(all_tracks['track'])
#
# TypeError: list indices must be integers or slices, not str

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7108/1532045083.py in <module>
# ----> 1 get_name_artists_from_playlist(all_tracks)
#
# ~\AppData\Local\Temp/ipykernel_7108/1065198932.py in get_name_artists_from_playlist(input_playlist)
#       1 def get_name_artists_from_playlist(input_playlist):
# ----> 2     return (list(map(get_name_artist_from_playlist_item,input_playlist["items"])))
#
# TypeError: list indices must be integers or slices, not str
